# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Coloque os arquivos das tabelas na pasta Content, por favor.")

# Caminhos dos arquivos CSV
caminho_arquivos = {
    "product": "/content/product.csv",
    "rideaddress_v1": "/content/rideaddress_v1.csv",
    "rideestimative_v3": "/content/rideestimative_v3.csv",
    "ride_v2": "/content/ride_v2.csv"
}

dataframes = {}

# Coleta dos Dados Iniciais
for nome, path in caminho_arquivos.items():
    dataframes[nome] = pd.read_csv(path, delimiter=";")
print("")
print("Funcionando")
# Out:
# <ipython-input-4-d1aed99b7333>:17: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataframes[nome] = pd.read_csv(path, delimiter=";")
# Funcionando

# %%
# Descrição dos Dados
for nome, df in dataframes.items():
    print(f"\n### Primeiras 3 linhas do dataset {nome}:\n")
    print(df.head(3))

for nome, df in dataframes.items():
    print(f"\n### Estatísticas do datasett {nome}:\n")
    print(df.describe(include='all'))
    print("\nContagem dos valores únicos por coluna:\n")
    print(df.nunique())
# Out:
# ### Primeiras 3 linhas do dataset product:
#
#   ProductID  ProviderID  CategoryID Description
# 0     99POP           3           1       99POP
# 1         1           1           5  Taxi Comum
# 2         2           1           6   Executivo
#
# ### Primeiras 3 linhas do dataset rideaddress_v1:
#
#    RideAddressID                                            Address  \
# 0        2334277  Rua João Pinheiro, 585 - Rua João Pinheiro - B...
# 1        2334278  Av. Dr. Nereu Ramos, 450 - Rocio Grande, São F...
# 2        2334279  Rodovia Rafael da Rocha Pires, 1883 - Rodovia ...
#
#                                               Street Number  \
# 0                                  Rua João Pinheiro    585
# 1  Av. Dr. Nereu Ramos, 450 - Rocio Grande, São F...    450
# 2                      Rodovia Rafael da Rocha Pires   1883
#
#                     Neighborhood City   State                  Lat  \
# 0              Rua João Pinheiro  NaN  Brasil  -26.329754299999998
# 1                            NaN  NaN     NaN          -26.2554657
# 2  Rodovia Rafael da Rocha Pires  NaN  Brasil          -27.4919788
#
#                    Lng  RideAddressTypeID   RideID
# 0  -48.840427999999996                  1  1183200
# 1          -48.6434197                  2  1183200
# 2  -48.528287999999996                  1  1183201
#
# ### Primeiras 3 linhas do dataset rideestimative_v3:
#
#    RideEstimativeID   RideID ProductID  WaitingTime  Price  \
# 0           8619946  1183200     Flash            8   89.0
# 1           8619947  1183200     UberX            6   89.0
# 2           8619948  1183200   Comfort           10  116.5
#
#                                  FareID  Selected  \
# 0  c6aaac64-5f89-4fc4-8b66-0251ec1c78a8         0
# 1  ff3cc941-93a8-4d0e-a274-bb988576d7d4         0
# 2  d7708871-2f2c-447d-81e6-a2d121863a2f         0
#
#    RideReasonSelectedEstimativeID  Fee
# 0                             NaN  0.0
# 1                             NaN  0.0
# 2                             NaN  0.0
#
# ### Primeiras 3 linhas do dataset ride_v2:
#
#     RideID                                UserID                     Schedule  \
# 0  1685755  e15b8cc3-5a67-4630-b89f-ee69f302b582  2025-02-10 14:31:10.8858446
# 1  1685754  5c3fb011-0aea-429a-8305-b88953b77df1  2025-02-10 14:26:35.3411403
# 2  1685753  d7e2f4dc-337f-45f5-b762-67b72b077abc  2025-02-10 14:23:45.2540905
#
#                         Create  RideStatusID  CompanyID  ProviderID  \
# 0  2025-02-10 14:31:10.9084221             1          2         NaN
# 1  2025-02-10 14:26:35.4169873             2        230         5.0
# 2  2025-02-10 14:24:32.7058722             2         52         3.0
#
#   RideProviderID  price                      Updated  CategoryID  TotalUsers  \
# 0            NaN   0.00  2025-02-10 14:31:10.9084233         NaN           1
# 1            NaN  30.45  2025-02-10 14:28:02.4656963         NaN           1
# 2            NaN  11.40  2025-02-10 14:24:46.5037165         NaN           1
#
#    Car  RideDriverLocationID  ScheduledRide
# 0  NaN                   NaN              0
# 1  NaN                   NaN              0
# 2  NaN                   NaN              0
#
# ### Estatísticas do datasett product:
#
#        ProductID  ProviderID  CategoryID Description
# count        237  237.000000  237.000000         237
# unique       236         NaN         NaN         166
# top        99POP         NaN         NaN  Taxi Comum
# freq           2         NaN         NaN          28
# mean         NaN   10.054852    3.426160         NaN
# std          NaN   11.933127    2.527776         NaN
# min          NaN    1.000000    1.000000         NaN
# 25%          NaN    2.000000    1.000000         NaN
# 50%          NaN    3.000000    2.000000         NaN
# 75%          NaN   17.000000    5.000000         NaN
# max          NaN   44.000000   10.000000         NaN
#
# Contagem dos valores únicos por coluna:
#
# ProductID      236
# ProviderID      37
# CategoryID       8
# Description    166
# dtype: int64
#
# ### Estatísticas do datasett rideaddress_v1:
#
#         RideAddressID                                            Address  \
# count    1.000000e+06                                            1000000
# unique            NaN                                             140185
# top               NaN  Esplanada dos Ministérios Bloco K - Bloco K - ...
# freq              NaN                                               3629
# mean     2.835428e+06                                                NaN
# std      2.897236e+05                                                NaN
# min      2.334277e+06                                                NaN
# 25%      2.584301e+06                                                NaN
# 50%      2.835352e+06                                                NaN
# 75%      3.086679e+06                                                NaN
# max      3.336838e+06                                                NaN
#
#                   Street  Number Neighborhood       City   State  \
# count             998103  784370       410032     617798  768544
# unique             95524    8399        46335       2805     407
# top     Avenida Angélica     s/n       Centro  São Paulo      SP
# freq                6440   13020        10179     127724  153358
# mean                 NaN     NaN          NaN        NaN     NaN
# std                  NaN     NaN          NaN        NaN     NaN
# min                  NaN     NaN          NaN        NaN     NaN
# 25%                  NaN     NaN          NaN        NaN     NaN
# 50%                  NaN     NaN          NaN        NaN     NaN
# 75%                  NaN     NaN          NaN        NaN     NaN
# max                  NaN     NaN          NaN        NaN     NaN
#
#                    Lat             Lng  RideAddressTypeID        RideID
# count   1000000.000000  1000000.000000          1000000.0  1.000000e+06
# unique   132752.000000   132570.000000                NaN           NaN
# top         -15.794738      -47.873794                NaN           NaN
# freq       7433.000000     7433.000000                NaN           NaN
# mean               NaN             NaN                1.5  1.434348e+06
# std                NaN             NaN                0.5  1.453850e+05
# min                NaN             NaN                1.0  1.183200e+06
# 25%                NaN             NaN                1.0  1.308224e+06
# 50%                NaN             NaN                1.5  1.434272e+06
# 75%                NaN             NaN                2.0  1.560596e+06
# max                NaN             NaN                2.0  1.685757e+06
#
# Contagem dos valores únicos por coluna:
#
# RideAddressID        1000000
# Address               140185
# Street                 95524
# Number                  8399
# Neighborhood           46335
# City                    2805
# State                    407
# Lat                   132752
# Lng                   132570
# RideAddressTypeID          2
# RideID                500000
# dtype: int64
#
# ### Estatísticas do datasett rideestimative_v3:
#
#         RideEstimativeID        RideID ProductID   WaitingTime         Price  \
# count       2.000000e+06  2.000000e+06   2000000  2.000000e+06  2.000000e+06
# unique               NaN           NaN        34           NaN           NaN
# top                  NaN           NaN     UberX           NaN           NaN
# freq                 NaN           NaN    235734           NaN           NaN
# mean        9.620000e+06  1.309709e+06       NaN  6.158906e+00  3.947684e+01
# std         5.774883e+05  7.117834e+04       NaN  2.910856e+00  1.106350e+02
# min         8.619946e+06  1.183200e+06       NaN  0.000000e+00  0.000000e+00
# 25%         9.119946e+06  1.247987e+06       NaN  4.000000e+00  1.551000e+01
# 50%         9.619948e+06  1.312332e+06       NaN  6.000000e+00  2.673000e+01
# 75%         1.011995e+07  1.372959e+06       NaN  7.000000e+00  4.730000e+01
# max         1.272614e+07  1.425244e+06       NaN  6.800000e+01  1.542012e+04
#
#                                       FareID      Selected  \
# count                                1181775  2.000000e+06
# unique                                   485           NaN
# top     84b66fec-3a48-4e62-b403-2fb9a420900a           NaN
# freq                                   69840           NaN
# mean                                     NaN  1.170105e-01
# std                                      NaN  3.214329e-01
# min                                      NaN  0.000000e+00
# 25%                                      NaN  0.000000e+00
# 50%                                      NaN  0.000000e+00
# 75%                                      NaN  0.000000e+00
# max                                      NaN  1.000000e+00
#
#         RideReasonSelectedEstimativeID           Fee
# count                    234021.000000  2.000000e+06
# unique                             NaN           NaN
# top                                NaN           NaN
# freq                               NaN           NaN
# mean                          2.060161 -2.492200e-02
# std                           1.434068  7.265467e-01
# min                           1.000000 -2.000000e+01
# 25%                           1.000000  0.000000e+00
# 50%                           1.000000  0.000000e+00
# 75%                           4.000000  0.000000e+00
# max                           4.000000  5.000000e+00
#
# Contagem dos valores únicos por coluna:
#
# RideEstimativeID                  2000000
# RideID                             239270
# ProductID                              34
# WaitingTime                            62
# Price                               17239
# FareID                                485
# Selected                                2
# RideReasonSelectedEstimativeID          2
# Fee                                     4
# dtype: int64
#
# ### Estatísticas do datasett ride_v2:
#
#               RideID                                UserID  \
# count   5.000000e+05                                500000
# unique           NaN                                 10793
# top              NaN  ab1a5587-d603-4bf7-a477-1d7c678bb111
# freq             NaN                                  4309
# mean    1.434347e+06                                   NaN
# std     1.453845e+05                                   NaN
# min     1.183200e+06                                   NaN
# 25%     1.308224e+06                                   NaN
# 50%     1.434272e+06                                   NaN
# 75%     1.560596e+06                                   NaN
# max     1.685755e+06                                   NaN
#
#                            Schedule                       Create  \
# count                        500000                       500000
# unique                       499709                       499982
# top     2024-01-02 17:38:00.0000000  2021-10-29 21:35:29.4454155
# freq                              5                            2
# mean                            NaN                          NaN
# std                             NaN                          NaN
# min                             NaN                          NaN
# 25%                             NaN                          NaN
# 50%                             NaN                          NaN
# 75%                             NaN                          NaN
# max                             NaN                          NaN
#
#          RideStatusID      CompanyID     ProviderID RideProviderID  \
# count   500000.000000  500000.000000  228157.000000          21440
# unique            NaN            NaN            NaN          21432
# top               NaN            NaN            NaN    6,53001E+13
# freq              NaN            NaN            NaN              2
# mean         2.313840      70.643076       4.540829            NaN
# std          1.170656      52.732732       6.780227            NaN
# min          1.000000       1.000000       1.000000            NaN
# 25%          2.000000      40.000000       2.000000            NaN
# 50%          2.000000      52.000000       3.000000            NaN
# 75%          2.000000      75.000000       3.000000            NaN
# max         12.000000     292.000000      41.000000            NaN
#
#                 price                      Updated    CategoryID  \
# count   500000.000000                       500000  24714.000000
# unique            NaN                       499978           NaN
# top               NaN  2024-12-16 17:09:36.2847714           NaN
# freq              NaN                            2           NaN
# mean        34.108806                          NaN      3.670349
# std        175.625387                          NaN      1.492551
# min          0.000000                          NaN      1.000000
# 25%         12.500000                          NaN      2.000000
# 50%         21.150000                          NaN      5.000000
# 75%         36.550000                          NaN      5.000000
# max      15254.800000                          NaN     10.000000
#
#            TotalUsers      Car  RideDriverLocationID  ScheduledRide
# count   500000.000000    14944          14864.000000  500000.000000
# unique            NaN      741                   NaN            NaN
# top               NaN  COROLLA                   NaN            NaN
# freq              NaN      980                   NaN            NaN
# mean         1.079946      NaN          10774.742196       0.000424
# std          0.381338      NaN           4388.294986       0.020587
# min          0.000000      NaN           3048.000000       0.000000
# 25%          1.000000      NaN           7003.750000       0.000000
# 50%          1.000000      NaN          10799.500000       0.000000
# 75%          1.000000      NaN          14576.250000       0.000000
# max          4.000000      NaN          18361.000000       1.000000
#
# Contagem dos valores únicos por coluna:
#
# RideID                  500000
# UserID                   10793
# Schedule                499709
# Create                  499982
# RideStatusID                 8
# CompanyID                  127
# ProviderID                  32
# RideProviderID           21432
# price                    15647
# Updated                 499978
# CategoryID                   6
# TotalUsers                   5
# Car                        741
# RideDriverLocationID     14864
# ScheduledRide                2
# dtype: int64

# %%
# Exploração dos Dados:
ride_estimative_df = dataframes["rideestimative_v3"]

plt.figure(figsize=(10, 5))
ride_estimative_df["ProductID"].value_counts().plot(kind="bar")
plt.title("Produtos Mais Pedidos")
plt.xlabel("Produto")
plt.ylabel("Quantidade de Pedidos")
plt.xticks(rotation=45)
plt.show()

produtos_ordem = ride_estimative_df.groupby("ProductID")["WaitingTime"].mean().sort_values(ascending=False)
plt.figure(figsize=(10, 5))
plt.plot(produtos_ordem, marker='o', linestyle='-')
plt.title("Tempo de Espera por Produto")
plt.xlabel("Produto")
plt.ylabel("Tempo de Espera (em minutos)")
plt.xticks(rotation=45)
plt.show()

# %%
# Qualidade dos Dados
for nome, df in dataframes.items():
    print(f"\n### Qualidade dos Dados no dataset {nome}:\n")
    print("Valores ausentes por coluna:")
    print(df.isnull().sum())
    print("\nInformações duplicadas:")
    print(df.duplicated().sum())
# Out:
# ### Qualidade dos Dados no dataset product:
#
# Valores ausentes por coluna:
# ProductID      0
# ProviderID     0
# CategoryID     0
# Description    0
# dtype: int64
#
# Informações duplicadas:
# 0
#
# ### Qualidade dos Dados no dataset rideaddress_v1:
#
# Valores ausentes por coluna:
# RideAddressID             0
# Address                   0
# Street                 1897
# Number               215630
# Neighborhood         589968
# City                 382202
# State                231456
# Lat                       0
# Lng                       0
# RideAddressTypeID         0
# RideID                    0
# dtype: int64
#
# Informações duplicadas:
# 0
#
# ### Qualidade dos Dados no dataset rideestimative_v3:
#
# Valores ausentes por coluna:
# RideEstimativeID                        0
# RideID                                  0
# ProductID                               0
# WaitingTime                             0
# Price                                   0
# FareID                             818225
# Selected                                0
# RideReasonSelectedEstimativeID    1765979
# Fee                                     0
# dtype: int64
#
# Informações duplicadas:
# 0
#
# ### Qualidade dos Dados no dataset ride_v2:
#
# Valores ausentes por coluna:
# RideID                       0
# UserID                       0
# Schedule                     0
# Create                       0
# RideStatusID                 0
# CompanyID                    0
# ProviderID              271843
# RideProviderID          478560
# price                        0
# Updated                      0
# CategoryID              475286
# TotalUsers                   0
# Car                     485056
# RideDriverLocationID    485136
# ScheduledRide                0
# dtype: int64
#
# Informações duplicadas:
# 0
